# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import keras
from keras.layers import Conv2D
import tensorflow as tf

# %%
from keras.models import Sequential
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout, ZeroPadding2D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/datasets/flowers'

# %%
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, validation_split=0.2)

# %%
train_generator = data_generator.flow_from_directory(DATA_PATH, target_size=(224,224), color_mode='rgb',class_mode='categorical', batch_size=32, subset='training')
# Out:
# Found 3457 images belonging to 5 classes.

# %%
val_generator = data_generator.flow_from_directory(DATA_PATH, target_size=(224,224), color_mode='rgb',class_mode='categorical', batch_size=32, subset='validation')
# Out:
# Found 860 images belonging to 5 classes.

# %%
model = Sequential()

# first block
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same',input_shape=(224,224, 3)))
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# second block
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# third block
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# forth block
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# fifth block
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# sixth block (classifier)
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# =================================================================
# Total params: 134,281,029
# Trainable params: 134,281,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
model.fit_generator(
    train_generator,
    epochs=20,
    steps_per_epoch=3457 // 32,
    validation_data= val_generator    
   )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 108/108 [==============================] - 2016s 18s/step - loss: 1.6118 - accuracy: 0.2356 - val_loss: 1.6015 - val_accuracy: 0.2279
# Epoch 2/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.6023 - accuracy: 0.2318 - val_loss: 1.5997 - val_accuracy: 0.2442
# Epoch 3/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.6001 - accuracy: 0.2426 - val_loss: 1.5987 - val_accuracy: 0.2442
# Epoch 4/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.5991 - accuracy: 0.2423 - val_loss: 1.5985 - val_accuracy: 0.2442
# Epoch 5/20
# 108/108 [==============================] - 100s 926ms/step - loss: 1.6007 - accuracy: 0.2455 - val_loss: 1.5998 - val_accuracy: 0.2442
# Epoch 6/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.5996 - accuracy: 0.2426 - val_loss: 1.5986 - val_accuracy: 0.2442
# Epoch 7/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.6005 - accuracy: 0.2394 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 8/20
# 108/108 [==============================] - 100s 923ms/step - loss: 1.6004 - accuracy: 0.2435 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 9/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.5998 - accuracy: 0.2347 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 10/20
# 108/108 [==============================] - 100s 925ms/step - loss: 1.6004 - accuracy: 0.2444 - val_loss: 1.5983 - val_accuracy: 0.2442
# Epoch 11/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.5989 - accuracy: 0.2429 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 12/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.6005 - accuracy: 0.2371 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 13/20
# 108/108 [==============================] - 100s 924ms/step - loss: 1.5994 - accuracy: 0.2432 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 14/20
# 108/108 [==============================] - 100s 925ms/step - loss: 1.5995 - accuracy: 0.2432 - val_loss: 1.5983 - val_accuracy: 0.2442
# Epoch 15/20
# 108/108 [==============================] - 100s 926ms/step - loss: 1.5990 - accuracy: 0.2453 - val_loss: 1.5985 - val_accuracy: 0.2442
# Epoch 16/20
# 108/108 [==============================] - 100s 923ms/step - loss: 1.5992 - accuracy: 0.2444 - val_loss: 1.5986 - val_accuracy: 0.2442
# Epoch 17/20
# 108/108 [==============================] - 100s 926ms/step - loss: 1.6000 - accuracy: 0.2409 - val_loss: 1.5991 - val_accuracy: 0.2442
# Epoch 18/20
# 108/108 [==============================] - 100s 923ms/step - loss: 1.6000 - accuracy: 0.2441 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 19/20
# 108/108 [==============================] - 100s 925ms/step - loss: 1.5994 - accuracy: 0.2450 - val_loss: 1.5984 - val_accuracy: 0.2442
# Epoch 20/20
# 108/108 [==============================] - 100s 926ms/step - loss: 1.5995 - accuracy: 0.2418 - val_loss: 1.5985 - val_accuracy: 0.2442
